# %%
from huggingface_hub import InferenceClient
client = InferenceClient("Datou1111/shou_xin", token="hf_xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")

# output is a PIL.Image object
image = client.text_to_image("Astronaut riding a camel on the moon ")
image2 = client.text_to_image("shou_xin, A pencil sketch of steve jobs, minimalist, impressionism, negative space ")

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024>

# %%
image2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024>
